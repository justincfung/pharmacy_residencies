# %%
import selenium.webdriver
import time
import csv
import gc
import re
import pandas as pd
import requests
import random
from multiprocessing.pool import ThreadPool
from selenium.common.exceptions import NoSuchElementException, NoSuchWindowException, TimeoutException, WebDriverException

import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
from selenium.webdriver.common.proxy import Proxy, ProxyType

# %% [markdown]
# # Code Scraping

# %%
def main_page_scraping():
# ---------------------------------------------------------------------------------------------------------------------
    # write to designated file
    def write_to_file(file, var):
        with open(file, 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(var)

    def grab_ashp_codes():
        ashp_code_0 = driver.find_element_by_xpath('//div[@class="flex-grid"]/child::div/child::div/following-sibling::div/following-sibling::div').text
        ashp_code_1 = driver.find_element_by_xpath('//div[@class="flex-grid"]/child::div/following-sibling::div/child::div/following-sibling::div/following-sibling::div').text
        ashp_code_2 = driver.find_element_by_xpath('//div[@class="flex-grid"]/child::div/following-sibling::div/following-sibling::div/child::div/following-sibling::div/following-sibling::div').text
        ashp_code_3 = driver.find_element_by_xpath('//div[@class="flex-grid"]/child::div/following-sibling::div/following-sibling::div/following-sibling::div/child::div/following-sibling::div/following-sibling::div').text
        ashp_code_4 = driver.find_element_by_xpath('//div[@class="flex-grid"]/child::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/child::div/following-sibling::div/following-sibling::div').text
        ashp_code_5 = driver.find_element_by_xpath('//div[@class="flex-grid"]/child::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/child::div/following-sibling::div/following-sibling::div').text
        ashp_code_6 = driver.find_element_by_xpath('//div[@class="flex-grid"]/child::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/child::div/following-sibling::div/following-sibling::div').text
        ashp_code_7 = driver.find_element_by_xpath('//div[@class="flex-grid"]/child::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/child::div/following-sibling::div/following-sibling::div').text
        ashp_code_8 = driver.find_element_by_xpath('//div[@class="flex-grid"]/child::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/child::div/following-sibling::div/following-sibling::div').text
        ashp_code_9 = driver.find_element_by_xpath('//div[@class="flex-grid"]/child::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/child::div/following-sibling::div/following-sibling::div').text
        ashp_code_10 = driver.find_element_by_xpath('//div[@class="flex-grid"]/child::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/child::div/following-sibling::div/following-sibling::div').text
        ashp_code_11 = driver.find_element_by_xpath('//div[@class="flex-grid"]/child::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/child::div/following-sibling::div/following-sibling::div').text
        ashp_code_12 = driver.find_element_by_xpath('//div[@class="flex-grid"]/child::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/child::div/following-sibling::div/following-sibling::div').text
        ashp_code_13 = driver.find_element_by_xpath('//div[@class="flex-grid"]/child::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/child::div/following-sibling::div/following-sibling::div').text
        ashp_code_14 = driver.find_element_by_xpath('//div[@class="flex-grid"]/child::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/following-sibling::div/child::div/following-sibling::div/following-sibling::div').text
        
        ashp_codes = [ashp_code_0, ashp_code_1, ashp_code_2, ashp_code_3, ashp_code_4, ashp_code_5, ashp_code_6, ashp_code_7, ashp_code_8, ashp_code_9, ashp_code_10, ashp_code_11, ashp_code_12, ashp_code_13, ashp_code_14]
        
        return ashp_codes

    def click_next_button():
        driver.find_element_by_xpath('//span[@class="au-target pager-button pager-next"]').click()
        driver.implicitly_wait(3)
    
    def total_results():
        driver_results = driver.find_element_by_xpath('//div[@class="inline-block right-10"]').text
        results_regex = re.compile(r'of (\d+) results')
        mo = results_regex.search(driver_results)
        total_results = int(mo.group(1))
        return int(round(total_results/15))

# ---------------------------------------------------------------------------------------------------------------------
    main_page = 'https://accreditation.ashp.org/directory/#/program/residency'
    outfile = r'C:\Users\justin.fung\pharmacy\test.csv'
    
    # Create the .csv file with column names
    with open(outfile, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['id'])
    
    opts = selenium.webdriver.firefox.options.Options()
    # opts.headless = True
    driver = selenium.webdriver.Firefox(options=opts)
# ---------------------------------------------------------------------------------------------------------------------
    try:
        driver.get(main_page)
        driver.implicitly_wait(7)
        driver.find_element_by_xpath('//button[contains(text(), "Search")]').click()
        driver.implicitly_wait(3)
        i = 0
        while i < total_results():
            write_to_file(outfile, grab_ashp_codes())
            click_next_button()
            i += 1
        driver.close()
# ---------------------------------------------------------------------------------------------------------------------
    # Error Logging
    except TimeoutException:
        print('timeout')
        pass
    except WebDriverException:
        print('webdriver')
        pass
# -----------------------------
main_page_scraping()

# %% [markdown]
# # ASHP Residency Scraping Function

# %%
def ashp_residency_scrape(_id):
# write to designated file
    def write_to_file(file, var):
        try:
            with open(file, 'a', newline='', encoding='utf-8') as f:
                writer = csv.writer(f)
                writer.writerow(var)
        except UnicodeDecodeError:
            var = [_id]
            with open(file, 'a', newline='') as f:
                writer = csv.writer(f)
                writer.writerow(var)
# ---------------------------------------------------------------------------------------------------------------------
    opts = selenium.webdriver.firefox.options.Options()
    opts.headless = True

    driver = selenium.webdriver.Firefox(options=opts)
    url = 'https://accreditation.ashp.org/directory/#/program/residency/programInfo'
# ---------------------------------------------------------------------------------------------------------------------
    try:
        driver.get('{1}/{0}'.format(str(_id), str(url)))
        driver.implicitly_wait(7)
# ---------------------------------------------------------------------------------------------------------------------
# Location Name
        try:
            name = driver.find_element_by_xpath('//div[@class="program-info flex-info-display padded-container"]/child::h1').text
        except (NoSuchElementException, NoSuchWindowException):
            name = None
# ---------------------------------------------------------------------------------------------------------------------
# Address
        try:
            main_address = driver.find_element_by_xpath('//div[@class="primary-address"]/child::div').text
        except (NoSuchElementException, NoSuchWindowException):
            main_address = None
        try:
            city = driver.find_element_by_xpath('//div[@class="primary-address"]/child::div/following-sibling::div/child::span').text
        except (NoSuchElementException, NoSuchWindowException):
            city = None
        try:
            state = driver.find_element_by_xpath('//div[@class="primary-address"]/child::div/following-sibling::div/child::span/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            state = None
        try:
            zip_code = driver.find_element_by_xpath('//div[@class="primary-address"]/child::div/following-sibling::div/child::span/following-sibling::span/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            zip_code = None
# ---------------------------------------------------------------------------------------------------------------------
# ASHP Codes
        try:
            code = driver.find_element_by_xpath('//span[contains(text(), "Code:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            code = None
        try:
            nms_code = driver.find_element_by_xpath('//span[contains(text(), "NMS Code:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            nms_code = None
# ---------------------------------------------------------------------------------------------------------------------
# Type
        try:
            accrediation_status = driver.find_element_by_xpath('//span[contains(text(), "Accreditation Status:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            accrediation_status = None
        try:
            organization_type = driver.find_element_by_xpath('//span[contains(text(), "Organization Type:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            organization_type = None
# ---------------------------------------------------------------------------------------------------------------------
#     Category
        try:
            category = driver.find_element_by_xpath('//span[contains(text(), "Category:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            category = None
        try:
            sub_category = driver.find_element_by_xpath('//span[contains(text(), "Sub-Category:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            sub_category = None
# ---------------------------------------------------------------------------------------------------------------------
# Contact
        try:
            residency_program_director_name = driver.find_element_by_xpath('//div[contains(text(), "Residency Program Director")]/following-sibling::div/child::div').text
        except (NoSuchElementException, NoSuchWindowException):
            residency_program_director_name = None
        try:
            residency_program_director_phone_number = driver.find_element_by_xpath('//div[contains(text(), "Residency Program Director")]/following-sibling::div/child::div/following-sibling::div/child::span').text
        except (NoSuchElementException, NoSuchWindowException):
            residency_program_director_phone_number = None
        try:
            residency_program_director_email = driver.find_element_by_xpath('//div[contains(text(), "Residency Program Director")]/following-sibling::div/child::div/following-sibling::div/following-sibling::div/child::a').text
        except (NoSuchElementException, NoSuchWindowException):
            residency_program_director_email = None
        try:
            director_of_pharmacy_name = driver.find_element_by_xpath('//div[contains(text(), "Director of Pharmacy")]/following-sibling::div/child::div').text
        except (NoSuchElementException, NoSuchWindowException):
            director_of_pharmacy_name = None
        try:
            director_of_pharmacy_phone_number = driver.find_element_by_xpath('//div[contains(text(), "Director of Pharmacy")]/following-sibling::div/child::div/following-sibling::div/child::span').text
        except (NoSuchElementException, NoSuchWindowException):
            director_of_pharmacy_phone_number = None
        try:
            director_of_pharmacy_email = driver.find_element_by_xpath('//div[contains(text(), "Director of Pharmacy")]/following-sibling::div/child::div/following-sibling::div/following-sibling::div/child::a').text
        except (NoSuchElementException, NoSuchWindowException):
            director_of_pharmacy_email = None
        try:
            program_contact_name = driver.find_element_by_xpath('//div[contains(text(), "Program Contact")]/following-sibling::div/child::div').text
        except (NoSuchElementException, NoSuchWindowException):
            program_contact_name = None
        try:
            program_contact_phone_number = driver.find_element_by_xpath('//div[contains(text(), "Program Contact")]/following-sibling::div/child::div/following-sibling::div/child::span').text
        except (NoSuchElementException, NoSuchWindowException):
            program_contact_phone_number = None
        try:
            program_contact_email = driver.find_element_by_xpath('//div[contains(text(), "Program Contact")]/following-sibling::div/child::div/following-sibling::div/following-sibling::div/child::a').text
        except (NoSuchElementException, NoSuchWindowException):
            program_contact_email = None

# ---------------------------------------------------------------------------------------------------------------------
# Demographic
        try:
            starting_date = driver.find_element_by_xpath('//span[contains(text(), "Starting Date:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            starting_date = None
        try:
            application_deadline = driver.find_element_by_xpath('//span[contains(text(), "Application Deadline:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            application_deadline = None
        try:
            duration_type = driver.find_element_by_xpath('//span[contains(text(), "Duration/Type:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            duration_type = None
        try:
            no_positions = driver.find_element_by_xpath('//span[contains(text(), "Number Positions:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            no_positions = None
        try:
            estimated_stipend = driver.find_element_by_xpath('//span[contains(text(), "Estimated Stipend:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            estimated_stipend = None
        try:
            interview_required = driver.find_element_by_xpath('//span[contains(text(), "Interview Required:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            interview_required = None
        try:
            residency_special_features = driver.find_element_by_xpath('//span[contains(text(), "Residency Special Features:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            residency_special_features = None
        try:
            fringe_benefits = driver.find_element_by_xpath('//span[contains(text(), "Fringe Benefits:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            fringe_benefits = None
        try:
            special_reqs_for_acceptance = driver.find_element_by_xpath('//span[contains(text(), "Special Requirements for Acceptance:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            special_reqs_for_acceptance = None
        try:
            training_site_type = driver.find_element_by_xpath('//span[contains(text(), "Training Site Type:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            training_site_type = None
        try:
            owner_affiliate = driver.find_element_by_xpath('//span[contains(text(), "Owner Affiliate:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            owner_affiliate = None
        try:
            model_type = driver.find_element_by_xpath('//span[contains(text(), "Model Type(s):")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            model_type = None
        try:
            tax_status = driver.find_element_by_xpath('//span[contains(text(), "Tax Status:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            tax_status = None
        try:
            no_pharmacist_staff = driver.find_element_by_xpath('//span[contains(text(), "Pharmacist Staff:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            no_pharmacist_staff = None
        try:
            no_non_pharmacist_staff = driver.find_element_by_xpath('//span[contains(text(), "Non-Pharmacist Staff:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            no_non_pharmacist_staff = None
        try:
            site_special_features = driver.find_element_by_xpath('//span[contains(text(), "Site Special Features:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            site_special_features = None
        try:
            no_patient_care_centers = driver.find_element_by_xpath('//span[contains(text(), "Number of Patient Care Centers:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            no_patient_care_centers = None
# ---------------------------------------------------------------------------------------------------------------------
# Write variables to csv file
        var = [name, main_address, city, state, zip_code, code, nms_code, accrediation_status, organization_type, 
               category, sub_category, residency_program_director_name, residency_program_director_phone_number, 
               residency_program_director_email, director_of_pharmacy_name, director_of_pharmacy_phone_number, 
               director_of_pharmacy_email, program_contact_name, program_contact_phone_number, program_contact_email, 
               starting_date, application_deadline, duration_type, no_positions, estimated_stipend, interview_required, 
               residency_special_features, fringe_benefits, special_reqs_for_acceptance, training_site_type, 
               owner_affiliate, model_type, tax_status, no_pharmacist_staff, no_non_pharmacist_staff, 
               site_special_features, no_patient_care_centers]
        try:
            write_to_file(outfile, var)
        except UnicodeDecodeError:
            print(code)
            pass
        driver.close()
# ---------------------------------------------------------------------------------------------------------------------
# Error Logging
    except TimeoutException:  
        var = [_id, 'Timed Out']
        write_to_file(error_file, var)
        driver.close()
        pass
    except WebDriverException:
        var = [_id, 'Invalid URL']
        write_to_file(error_file, var)
        driver.close()
        pass
# ---------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------

# Multi-threading Function
def multi_threading(lst, process, division):
    i = 0
    iteration = 0

    while i < len(lst):
        gc.collect()
        try:
            sub_list = lst[i:(i + division)]
            i += division
        except IndexError:
            sub_list = lst[i:len(lst)]
        with ThreadPool(5) as pool:
            pool.map(process, sub_list)
            pool.close()
        iteration += 1

# %% [markdown]
# # Main

# %%
codes = pd.read_csv('pharmacy_residency_codes.csv')

residency_ids = codes['id'].tolist()

outfile = r'C:\Users\justin.fung\pharmacy\pharmacy_residency_info.csv'
error_file = r'C:\Users\justin.fung\pharmacy\pharmacy_residency_info_error.csv'

Create the .csv file with column names
with open(outfile, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['name', 'main_address', 'city', 'state', 'zip_code', 'code', 'nms_code', 'accrediation_status', 
                     'organization_type', 'category', 'sub_category', 'residency_program_director_name', 
                     'residency_program_director_phone_number','residency_program_director_email', 
                     'director_of_pharmacy_name', 'director_of_pharmacy_phone_number', 'director_of_pharmacy_email', 
                     'program_contact_name', 'program_contact_phone_number', 'program_contact_email', 'starting_date', 
                     'application_deadline', 'duration_type', 'no_positions', 'estimated_stipend', 'interview_required',
                     'residency_special_features', 'fringe_benefits', 'special_reqs_for_acceptance', 
                     'training_site_type', 'owner_affiliate', 'starting_date', 'tax_status', 'no_pharmacist_staff', 
                     'no_non_pharmacist_staff', 'site_special_features', 'no_patient_care_centers'])
    f.close

with open(error_file, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['id', 'error_message'])
    f.close

# %%
start = time.time()
multi_threading(residency_ids,ashp_residency_scrape,250)
print(f'Initial Scrape: {time.time()-start} seconds')

# %%
results = pd.read_csv('pharmacy_residency_info.csv')


redo_list = []
for i in codes['id'].tolist():
    if i in results['code'].drop_duplicates().tolist():
        pass
    else:
        redo_list.append(i)

# %%
start = time.time()
multi_threading(redo_list, ashp_residency_scrape, 40)
print(time.time()-start)

# %% [markdown]
# # Cleaning for Emails

# %%
def clean_up_scrape(_id):
    # write to designated file
    def write_to_file(file, var):
        try:
            with open(file, 'a', newline='', encoding='utf-8') as f:
                writer = csv.writer(f)
                writer.writerow(var)
        except UnicodeDecodeError:
            var = [_id]
            with open(file, 'a', newline='') as f:
                writer = csv.writer(f)
                writer.writerow(var)
# ---------------------------------------------------------------------------------------------------------------------
    opts = selenium.webdriver.firefox.options.Options()
    opts.headless = True

    driver = selenium.webdriver.Firefox(options=opts)
    new_file = r'C:\Users\justin.fung\pharmacy\pharmacy_residency_clean_up.csv'
    url = 'https://accreditation.ashp.org/directory/#/program/residency/programInfo'
# ---------------------------------------------------------------------------------------------------------------------
    try:
        driver.get('{1}/{0}'.format(str(_id), str(url)))
        driver.implicitly_wait(7)
# ---------------------------------------------------------------------------------------------------------------------
# Location Name
        try:
            starting_date = driver.find_element_by_xpath('//span[contains(text(), "Starting Date:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            starting_date = None
        try:
            total_beds = driver.find_element_by_xpath('//span[contains(text(), "Total Beds:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            total_beds = None
        try:
            average_daily_census = driver.find_element_by_xpath('//span[contains(text(), "Average Daily Census:")]/following-sibling::span').text
        except (NoSuchElementException, NoSuchWindowException):
            average_daily_census = None
# ---------------------------------------------------------------------------------------------------------------------
# Contact
        try:
            residency_program_director_email = driver.find_element_by_xpath('//div[contains(text(), "Residency Program Director")]/following-sibling::div/child::div/following-sibling::div/child::span').text
            if residency_program_director_email == 'Email:':
                residency_program_director_email = driver.find_element_by_xpath('//div[contains(text(), "Residency Program Director")]/following-sibling::div/child::div/following-sibling::div/child::span/following-sibling::a').text
            elif '@' in residency_program_director_email:
                residency_program_director_email = 'PHONE NUMBER'
            else:
                residency_program_director_email = ''
        except (NoSuchElementException, NoSuchWindowException):
            residency_program_director_email = None
#         return residency_program_director_email
    
        try:
            director_of_pharmacy_email = driver.find_element_by_xpath('//div[contains(text(), "Director of Pharmacy")]/following-sibling::div/child::div/following-sibling::div/child::span').text
            if director_of_pharmacy_email == 'Email:':
                director_of_pharmacy_email = driver.find_element_by_xpath('//div[contains(text(), "Director of Pharmacy")]/following-sibling::div/child::div/following-sibling::div/child::span/following-sibling::a').text
            elif '@' in director_of_pharmacy_email:
                director_of_pharmacy_email = 'PHONE NUMBER'
            else:
                director_of_pharmacy_email = ''
        except (NoSuchElementException, NoSuchWindowException):
            director_of_pharmacy_email = None
#         return director_of_pharmacy_email

        try:
            program_contact_email = driver.find_element_by_xpath('//div[contains(text(), "Program Contact")]/following-sibling::div/child::div/following-sibling::div/child::span').text
            if program_contact_email == 'Email:':
                program_contact_email = driver.find_element_by_xpath('//div[contains(text(), "Program Contact")]/following-sibling::div/child::div/following-sibling::div/child::span/following-sibling::a').text
            elif '@' in program_contact_email:
                program_contact_email = 'PHONE NUMBER'
            else:
                program_contact_email = ''
        except (NoSuchElementException, NoSuchWindowException):
            program_contact_email = None
#         return program_contact_email
# ---------------------------------------------------------------------------------------------------------------------
# Write variables to csv file
        var = [_id, starting_date, total_beds, average_daily_census, 
               residency_program_director_email, director_of_pharmacy_email, program_contact_email]
        try:
            write_to_file(new_file, var)
        except UnicodeDecodeError:
            print(code)
            pass
        driver.close()
# ---------------------------------------------------------------------------------------------------------------------
# Error Logging
    except TimeoutException:  
#         var = [_id, 'Timed Out']
#         write_to_file(error_file, var)
#         driver.close()
        pass
    except WebDriverException:
#         var = [_id, 'Invalid URL']
#         write_to_file(error_file, var)
#         driver.close()
        pass

# %%
new_file = r'C:\Users\justin.fung\pharmacy\pharmacy_residency_clean_up.csv'

# Create the .csv file with column names
with open(new_file, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['code', 'starting_date', 'total_beds', 'average_daily_census', 
                     'residency_program_director_email', 'directory_of_pharmacy_email', 'program_contact_email'])

# %%
start = time.time()
multi_threading(residency_ids, clean_up_scrape, 500)
print(time.time()-start)
# Out:
# 3513.41592168808

# %%
clean_df = pd.read_csv(new_file)

redo_list = []
for i in codes['id'].tolist():
    if i in clean_df['code'].drop_duplicates().tolist():
        pass
    else:
        redo_list.append(i)

# %%
start = time.time()
multi_threading(redo_list, clean_up_scrape, 25)
print(time.time()-start)
# Out:
# 24.29739737510681

# %% [markdown]
# # Final

# %%
full_df = results.drop_duplicates(subset=['code']).merge(clean_df.drop_duplicates(subset=['code']), on='code')

full_df['starting_date_x'] = full_df['starting_date_y'].tolist()
full_df['residency_program_director_email_x'] = [full_df['residency_program_director_email_y'].tolist()[counter] if full_df['residency_program_director_email_y'].tolist()[counter] is None else full_df['residency_program_director_email_x'].tolist()[counter] for counter in range(0, len(full_df))]
full_df['director_of_pharmacy_email'] = [full_df['directory_of_pharmacy_email'].tolist()[counter] if full_df['directory_of_pharmacy_email'].tolist()[counter] is None else full_df['director_of_pharmacy_email'].tolist()[counter] for counter in range(0, len(full_df))]
full_df['program_contact_email_x'] = [full_df['program_contact_email_y'].tolist()[counter] if full_df['program_contact_email_y'].tolist()[counter] is None else full_df['program_contact_email_x'].tolist()[counter] for counter in range(0, len(full_df))]
full_df = full_df.rename(columns=
                         {
                             'starting_date.1':'training_site_type', 
                             'residency_program_director_email_x': 'residency_program_director_email', 
                             'program_contact_email_x':'program_contact_email', 
                             'starting_date_x':'starting_date'
                         }
                        )
full_df = full_df.drop(columns=['starting_date_y', 'residency_program_director_email_y', 
                                'directory_of_pharmacy_email', 'program_contact_email_y'])

# %%
full_df.to_csv('final_pharmacy_residency_info.csv', index=False)
